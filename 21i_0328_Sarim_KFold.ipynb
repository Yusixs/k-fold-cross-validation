# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris['data'])
df['target'] = iris['target']
df.columns = ["Sepal Length", "Sepal Width", "Petal Length", "Petal Width", "Target"]
df
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width  Target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
df.mean()
# Out:
# Sepal Length    5.843333
# Sepal Width     3.057333
# Petal Length    3.758000
# Petal Width     1.199333
# Target          1.000000
# dtype: float64

# %%
df.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width      Target
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
print(len(df[df['Target'] == 0]))
print(len(df[df['Target'] == 1]))
print(len(df[df['Target'] == 2]))
# Out:
# 50
# 50
# 50

# %%
def train_test_split(df, number_of_splits):

  start = 0
  k_splits = [pd.DataFrame(columns = df.columns) for i in range(number_of_splits)]

  for i in df['Target'].unique():

    singleLabelDf = df[df['Target'] == i]
    index = int(len(singleLabelDf) / number_of_splits)

    for j in range(number_of_splits):
        k_splits[j] = pd.concat([k_splits[j],singleLabelDf[start:start+index]], ignore_index = True)

    start += index

  return k_splits

# %%
number_of_splits = 10

split = train_test_split(df, number_of_splits)
display(split)
# Out:
# [    Sepal Length  Sepal Width  Petal Length  Petal Width Target
#  0            5.1          3.5           1.4          0.2      0
#  1            4.9          3.0           1.4          0.2      0
#  2            4.7          3.2           1.3          0.2      0
#  3            4.6          3.1           1.5          0.2      0
#  4            5.0          3.6           1.4          0.2      0
#  5            5.7          2.8           4.5          1.3      1
#  6            6.3          3.3           4.7          1.6      1
#  7            4.9          2.4           3.3          1.0      1
#  8            6.6          2.9           4.6          1.3      1
#  9            5.2          2.7           3.9          1.4      1
#  10           6.5          3.2           5.1          2.0      2
#  11           6.4          2.7           5.3          1.9      2
#  12           6.8          3.0           5.5          2.1      2
# ...

# %%
for index in range(number_of_splits):
  split = train_test_split(df, number_of_splits)
  test = split.pop(index)
  train = split

  train = pd.DataFrame(columns = df.columns)
  for i in split[:-1]:
    train = pd.concat([train, i])

  x_train, y_train = train.iloc[:,:-1], train.iloc[:,-1]
  x_test, y_test = test.iloc[:,:-1], test.iloc[:,-1]

  knn = KNeighborsClassifier(n_neighbors=3)
  knn.fit(x_train, y_train.astype('int'))

  y_pred = knn.predict(x_test)
  print(f"Fold {index}: {accuracy_score(y_test.astype('int'), y_pred)}")
# Out:
# Fold 0: 1.0
# Fold 1: 1.0
# Fold 2: 1.0
# Fold 3: 1.0
# Fold 4: 1.0
# Fold 5: 1.0
# Fold 6: 1.0
# Fold 7: 1.0
# Fold 8: 1.0
# Fold 9: 1.0

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1]
y = df.iloc[:,-1].astype("int")
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)
print(f"Sklearn Train Test Split: {accuracy_score(y_test, y_pred)}")
# Out:
# Sklearn Train Test Split: 1.0
